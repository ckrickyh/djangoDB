# %%
import psycopg2

conn = psycopg2.connect("dbname=erb8dbmanager user=postgres password=admin1234 host=localhost port=5432")
cur = conn.cursor()

with open('/Users/rickyho/Documents/github/djangoDB/externalSources/TreePhoto.csv', 'r') as f:
    # Use copy_expert for the most control and speed
    sql = "COPY treeinvs_treephotourl (tree_tag_id, url) FROM STDIN WITH CSV HEADER DELIMITER ','"
    cur.copy_expert(sql, f)

conn.commit()
cur.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[1], line 3
#       1 import psycopg2
# ----> 3 conn = psycopg2.connect("dbname=erb8dbmanager user=postgres password=admin1234 host=localhost:5432")
#       4 cur = conn.cursor()
#       6 with open('/Users/rickyho/Documents/github/djangoDB/externalSources/TreePhoto.csv', 'r') as f:
#       7     # Use copy_expert for the most control and speed
#
# File ~/.pyenv/versions/3.12.12/lib/python3.12/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# ...
